# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import matplotlib.colors as colors 
from matplotlib.colors import TwoSlopeNorm
from matplotlib import colors as mcolors
from matplotlib.colors import ListedColormap
import matplotlib.ticker as ticker
import matplotlib.patches as mpatches
from mpl_toolkits.axisartist.parasite_axes import HostAxes, ParasiteAxes
from scipy.stats import linregress
from matplotlib import font_manager
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import cmaps

# %%
Tmax = np.array([17,19,18,20,27,15,13])
Tmin = np.array([3,7,2,6,9,0,-1])
day = np.array([1,2,3,4,5,6,7])
s,d,r,p,_ = linregress(day,Tmax)
s1,d1,r1,p1,_ = linregress(day,Tmin)

# %%
fig=plt.figure(figsize=(12,12))

'''#设置字体和字号
font_path = 'E:/chrome/tnw+simsun.ttf'
font_manager.fontManager.addfont(font_path)
prop = font_manager.FontProperties(fname=font_path)
#print(prop.get_name())  # 显示当前使用字体的名称
plt.rcParams['font.family'] = 'sans-serif' # 使用字体中的无衬线体
plt.rcParams['font.sans-serif'] = prop.get_name()  # 根据名称设置字体
plt.rcParams['font.size'] = 16 # 设置字体大小
plt.rcParams['axes.unicode_minus'] = False # 使坐标轴刻度标签正常显示正负号'''

#设置字体和字号
plt.rcParams['font.sans-serif'] = 'Times New Roman'
plt.rcParams['font.size'] = '16'
font = {'weight': 'bold','size': 16}

ax1 = fig.add_axes([0, 0, 0.55, 0.4])
ax1.set_ylim(-5,31)
ax1.set_xlim(1,7)
ax1.set_xlabel('Date',font,labelpad= 15)
ax1.set_ylabel('Temperature (℃)',font)
#ax1.set_title('(a)',font,loc='left')
ax1.plot(day,Tmax,lw=2.8,marker='o',color='#CD5555',ms='9',label='Daily maximum temperature',markeredgecolor = '#696969')
ax1.plot(day,Tmin,lw=2.8,marker='o',color='#4682B4',ms='9',label='Daily minimum temperature',markeredgecolor = '#696969')

ax1.set_xticks([1,2,3,4,5,6,7],('Mar 6th','Mar 7th','Mar 8th','Mar 9th','Mar 10th','Mar 11st','Mar 12nd'))
for a, b in zip(day, Tmax):
    plt.text(a, b+0.5, b, ha='center', va='bottom', fontsize=16,color='#CD5555')

for a, b in zip(day, Tmin):
    plt.text(a, b+0.5, b, ha='center', va='bottom', fontsize=16,color='#4682B4')

ax1.legend(frameon=False,loc="upper left")
ax1.axhline(y=0,c='grey',lw=1.0, ls="--")
ax1.axhline(y=5,c='grey',lw=1.0, ls="--")
ax1.axhline(y=10,c='grey',lw=1.0, ls="--")
ax1.axhline(y=15,c='grey',lw=1.0, ls="--")
ax1.axhline(y=20,c='grey',lw=1.0, ls="--")
ax1.axhline(y=25,c='grey',lw=1.0, ls="--")
ax1.axhline(y=30,c='grey',lw=1.0, ls="--")
ax1.spines['top'].set_linewidth('0')
ax1.spines['right'].set_linewidth('0')
ax1.grid(linestyle='--', alpha=0.5, linewidth=2)

#fig.savefig('D:/study/lunwen/figure/Tmax_Tmin.pdf',format='pdf',dpi=300,bbox_inches = 'tight')
#fig.savefig('D:/study/lunwen/figure/Tmax_Tmin.jpg',format='jpeg',dpi=300,bbox_inches = 'tight')

# %%
fig=plt.figure(figsize=(12,12))
#设置字体和字号
plt.rcParams['font.sans-serif'] = 'Times New Roman'
plt.rcParams['font.size'] = '16'
font = {'weight': 'bold','size': 16}

ax1 = fig.add_axes([0, 0, 0.55, 0.4])
ax1.set_ylim(-5,31)
ax1.set_xlim(0.5,7.5)
ax1.set_xlabel('Date',font,labelpad= 15)
ax1.set_ylabel('Temperature (℃)',font)
ax1.plot(day,Tmax,lw=2.8,marker='o',color='#CD5555',ms='9',label='Tmax',markeredgecolor = '#696969')
#ax1.set_xticks([])
ax1.tick_params(axis='x', width=0)
#ax1.annotate('Key Point', (4, 4), color='r')    # 在图上点(600, 4)处添加标注
ax1.set_title('A ',fontsize=16,loc='left')
#ax1.axvline(x=4,c='g',lw=1.0)
#ax1.axhline(y=0, c="g", lw=1.0)
ax1.legend(frameon=False,loc="upper left")
ax1.grid(linestyle='--', alpha=0.5, linewidth=2)

# %%
data = [0.6250,0.5714,0.5000,0.4000,0.3333,0.1250,0.5714,0.6667,0.5000,0.6000,0.8333,0.6667,0.6667]

# %%
fig = plt.figure(figsize=(8,10))

ax = fig.add_axes([0.1, 0.1, 0.5, 0.35])

font_path = 'E:/chrome/tnw+simsun.ttf'
font_manager.fontManager.addfont(font_path)
prop = font_manager.FontProperties(fname=font_path)
plt.rcParams['font.family'] = 'sans-serif' # 使用字体中的无衬线体
plt.rcParams['font.sans-serif'] = prop.get_name()  # 根据名称设置字体
plt.rcParams['font.size'] = 16 # 设置字体大小
plt.rcParams['axes.unicode_minus'] = False # 使坐标轴刻度标签正常显示正负号
ax.tick_params(axis="x", direction="in", which="major", length=6)
ax.tick_params(axis="y", direction="in", which="major", length=6)
ax.set_xticks([])
bar = ax.bar(0, np.mean(data), width = 0.8, color='#458B74',yerr = np.std(data),error_kw = {'ecolor' : 'black', 'capsize' :8},edgecolor="k")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xlim(-2,2)
ax.set_ylim(0,0.8)
ax.set_ylabel('性别比例 Sex ratio',fontsize=17)
ax.text(0.55, 0.68, '0.72')
ax.text(0.55, 0.52, '0.54')
ax.text(0.55, 0.35, '0.37')
ax.grid(linestyle='--', alpha=0.5, linewidth=2,color = 'grey')

fig.savefig('D:\work\奇奇怪怪\一张图.jpg',format='jpg',dpi=300,bbox_inches = 'tight')

# %%
from pyhdf.SD import SD, SDC
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

HDF = "G:\EARTHDATA\MCD43C4_061-20241008_113550\MCD43C4.A2024270.061.2024279055444.hdf"
data= SD(HDF,SDC.READ)
type(data)
data.datasets()
#NIRv = data.select('Nadir_Reflectance_Band2')
NIRv  = np.flipud(data.select('Nadir_Reflectance_Band2'))
NIRv= np.nan_to_num(NIRv, nan=32767)
print(NIRv)
NIRv[NIRv == 32767.0]= 0
# Out:
# [[32767 32767 32767 ... 32767 32767 32767]
#  [32767 32767 32767 ... 32767 32767 32767]
#  [32767 32767 32767 ... 32767 32767 32767]
#  ...
#  [32767 32767 32767 ... 32767 32767 32767]
#  [32767 32767 32767 ... 32767 32767 32767]
#  [32767 32767 32767 ... 32767 32767 32767]]

# %%
import cartopy.feature as cfeature
from cartopy.mpl import geoaxes
import cartopy.crs as ccrs

# %%
plt.pcolormesh(lon,lat,NIRv,cmap='coolwarm')
plt.colorbar()

# %%
lon  = np.linspace(-180, 180,7200)
lat  = np.linspace(-90,90,3600) 

#df  = pd.DataFrame(NIRv,index=lat,columns=lon)
#lst_anta = df.loc[:,:]
t = NIRv[0:600,:]
fig=plt.figure(figsize=(10,10))
#第一个图位置
ax1 = fig.add_axes([0.0,0.0,0.5,0.5],projection = ccrs.PlateCarree())
#ax.set_extent([-180,180,-90,-60],crs=ccrs.PlateCarree())
#ax.coastlines()
#ax.gridlines()
ax1 = ax.contourf(lon,lat,NIRv,transform=ccrs.PlateCarree(), cmap='coolwarm', origin='lower')
#设置colorbar的位置
#cax = fig.add_axes([ax1.get_position().x1+0.03,ax1.get_position().y0,0.02,ax1.get_position().height])
#添加colorbar
fig.colorbar(ax1)
#cbar = plt.colorbar(img, ax=ax, orientation='horizontal', pad=0.05)
#cbar.set_label('Temperature (°C)')
plt.show()
# Out:
# C:\Users\86186\AppData\Local\Temp\ipykernel_18080\2130832722.py:17: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   fig.colorbar(ax1)

# %%
import netCDF4 as nc
data = nc.Dataset(r"G:\EARTHDATA\MCD43C4_061-20241008_113550\MCD43C4.A2024270.061.2024279055444.hdf")
type(data)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [15], in <cell line: 2>()
#       1 import netCDF4 as nc
# ----> 2 data = nc.Dataset(r"G:\EARTHDATA\MCD43C4_061-20241008_113550\MCD43C4.A2024270.061.2024279055444.hdf")
#       3 type(data)
#
# File src\netCDF4\_netCDF4.pyx:2307, in netCDF4._netCDF4.Dataset.__init__()
#
# File src\netCDF4\_netCDF4.pyx:1925, in netCDF4._netCDF4._ensure_nc_success()
#
# OSError: [Errno -128] NetCDF: Attempt to use feature that was not turned on when netCDF was built.: b'G:\\EARTHDATA\\MCD43C4_061-20241008_113550\\MCD43C4.A2024270.061.2024279055444.hdf'

# %%
from pyhdf.SD import SD, SDC
 
HDF = "G:\EARTHDATA\MCD43C4_061-20241008_113550\MCD43C4.A2024270.061.2024279055444.hdf"
file = SD(HDF)
 
print(file.info())

datasets_dic = file.datasets()
 
for idx,sds in enumerate(datasets_dic.keys()):
    print(idx,sds)
# Out:
# (12, 6)
# 0 Nadir_Reflectance_Band1
# 1 Nadir_Reflectance_Band2
# 2 Nadir_Reflectance_Band3
# 3 Nadir_Reflectance_Band4
# 4 Nadir_Reflectance_Band5
# 5 Nadir_Reflectance_Band6
# 6 Nadir_Reflectance_Band7
# 7 Albedo_Quality
# 8 Local_Solar_Noon
# 9 Percent_Inputs
# 10 Percent_Snow
# 11 BRDF_Albedo_Uncertainty

# %%
import pandas as pd
df = pd.read_hdf(r'G:\EARTHDATA\MCD43C4_061-20241008_113550\MCD43C4.A2024270.061.2024279055444.hdf')
print(df.head())  # 查看DataFrame的前几行
print(df.info())  # 查看DataFrame的基本信息，如列名、数据类型、非空值数量等
# Out:
# ---------------------------------------------------------------------------
# HDF5ExtError                              Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.read_hdf(r'G:\EARTHDATA\MCD43C4_061-20241008_113550\MCD43C4.A2024270.061.2024279055444.hdf')
#       3 print(df.head())  # 查看DataFrame的前几行
#       4 print(df.info())
#
# File c:\Users\86186\anaconda3\lib\site-packages\pandas\io\pytables.py:429, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     426 if not exists:
#     427     raise FileNotFoundError(f"File {path_or_buf} does not exist")
# --> 429 store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     430 # can't auto open/close if we are using an iterator
#     431 # so delegate to the iterator
#     432 auto_close = True
#
# ...

# %%
import pandas as pd
# 设置工作目录，这里假设你使用的是相对路径，需要根据实际情况调整
# 在Python中设置工作目录的方式与R略有不同，以下是一种示例方法
import os
os.chdir("D:\study\组会\DATA\SOC\WoSIS\WoSIS_2019_September")

# 读取属性文件
attributes = pd.read_csv('wosis_201909_attributes.tsv', sep='\t')
# 读取剖面文件
profiles = pd.read_csv('wosis_201909_profiles.tsv', sep='\t')
# 读取化学数据文件
chemical = pd.read_csv('wosis_201909_layers_chemical.tsv', sep='\t')
# 读取物理数据文件
physical = pd.read_csv('wosis_201909_layers_physical.tsv', sep='\t')
# Out:
# C:\Users\86186\AppData\Local\Temp\ipykernel_8940\105369275.py:10: DtypeWarning: Columns (9,10,11,12,14,15,16,17,19,20,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   profiles = pd.read_csv('wosis_201909_profiles.tsv', sep='\t')
# C:\Users\86186\AppData\Local\Temp\ipykernel_8940\105369275.py:12: DtypeWarning: Columns (4,6,8,9,10,11,12,13,15,16,17,18,19,20,22,23,24,25,26,27,29,30,31,32,33,34,36,37,38,39,40,41,43,44,45,46,47,48,50,51,52,53,54,55,57,58,59,60,61,62,64,65,66,67,68,69,71,72,73,74,75,76,78,79,80,81,82,83,85,86,87,88,89,90,92,93,94,95,96,97,99,100,101,102,103,104,106,107,108,109,110,111,113,114,115,116,117,118,120,121,122,123,124,125,127,128,129,130,131,132,134,135,136,137,138,139,141,142,143,144,145,146,148,149,150,151,152) have mixed types. Specify dtype option on import or set low_memory=False.
#   chemical = pd.read_csv('wosis_201909_layers_chemical.tsv', sep='\t')
# ...

# %%
attributes
# Out:
#       code     type                                   attribute        unit  \
# 0   BDFI33  Horizon            Bulk density fine earth - 33 kPa      kg/dm³
# 1   BDFIAD  Horizon           Bulk density fine earth - air dry      kg/dm³
# 2   BDFIFM  Horizon       Bulk density fine earth - field moist      kg/dm³
# 3   BDFIOD  Horizon          Bulk density fine earth - oven dry      kg/dm³
# 4   BDWS33  Horizon            Bulk density whole soil - 33 kPa      kg/dm³
# 5   BDWSAD  Horizon           Bulk density whole soil - air dry      kg/dm³
# 6   BDWSFM  Horizon       Bulk density whole soil - field moist      kg/dm³
# 7   BDWSOD  Horizon          Bulk density whole soil - oven dry      kg/dm³
# 8   CECPH7  Horizon  Cation exchange capacity - buffered at pH7  cmol(c)/kg
# 9   CECPH8  Horizon  Cation exchange capacity - buffered at pH8  cmol(c)/kg
# 10    CFAO     Site                     Soil classification FAO    unitless
# ...

# %%
profiles
# Out:
#         profile_id      dataset_id country_id country_name  geom_accuracy  \
# 0            36897   {BE-UplandsI}         BE      Belgium       0.000001
# 1            36898   {BE-UplandsI}         BE      Belgium       0.000001
# 2            36899   {BE-UplandsI}         BE      Belgium       0.000001
# 3            36900   {BE-UplandsI}         BE      Belgium       0.000001
# 4            36901   {BE-UplandsI}         BE      Belgium       0.000001
# ...            ...             ...        ...          ...            ...
# 196493      623813  {WD-NWAFU-SCS}         CN        China       0.000001
# 196494      623814  {WD-NWAFU-SCS}         BR       Brazil       0.000001
# 196495      623815  {WD-NWAFU-SCS}         EC      Ecuador       0.000001
# 196496      623816  {WD-NWAFU-SCS}         CN        China       0.000001
# 196497      623817  {WD-NWAFU-SCS}         CN        China       0.000001
#
#          latitude   longitude   dsds  cfao_version cfao_major_group_code  ...  \
# ...

# %%
chemical
# Out:
#         profile_id  profile_layer_id  upper_depth  lower_depth layer_name  \
# 0            47010                 1          0.0         21.0         Ap
# 1            47010                 2         21.0         35.0         E1
# 2            47010                 3         35.0         56.0         E2
# 3            47010                 4         56.0         88.0         EB
# 4            47010                 5         88.0        120.0         Bv
# ...            ...               ...          ...          ...        ...
# 788533      623817           3178447         10.0         20.0        NaN
# 788534      623817           3178448         20.0         30.0        NaN
# 788535      623817           3178449         30.0         50.0        NaN
# 788536      623817           3178450         50.0         70.0        NaN
# 788537      623817           3178451         70.0        100.0        NaN
#
#        litter tceq_value  tceq_value_avg tceq_method tceq_date  ...  \
# ...

# %%
physical
# Out:
#         profile_id  profile_layer_id  upper_depth  lower_depth layer_name  \
# 0            47010                 1          0.0         21.0         Ap
# 1            47010                 2         21.0         35.0         E1
# 2            47010                 3         35.0         56.0         E2
# 3            47010                 4         56.0         88.0         EB
# 4            47010                 5         88.0        120.0         Bv
# ...            ...               ...          ...          ...        ...
# 702693      623817           3178447         10.0         20.0        NaN
# 702694      623817           3178448         20.0         30.0        NaN
# 702695      623817           3178449         30.0         50.0        NaN
# 702696      623817           3178450         50.0         70.0        NaN
# 702697      623817           3178451         70.0        100.0        NaN
#
#        litter bdfi33_value  bdfi33_value_avg bdfi33_method bdfi33_date  ...  \
# ...
